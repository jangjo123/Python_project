# %%
# %pip install pygame
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\ccjkh\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
#region 처음한거
import pygame
from pygame.locals import *
from enum import Enum, auto

class State(Enum):
    Idle = auto()
    Run = auto()
    Jump = auto()

_state = State.Idle

screen = pygame.display.set_mode((800,600))
pygame.init()

running = True

def IDLE():
    return

def RUN():
    return

def JUMP():
    return

def Get_Png(PngName):
    return pygame.image.load(PngName+".png")

def Animation(state):
    if state == State.Run:
        print("Move")

    elif _state == State.Jump:
        print("Jump")

    else: None#print("Idle")

def Input(eventKey):

    if event.type == KEYDOWN:
        if event.key == K_RIGHT:
            _state = State.Run
            RUN()
                
        elif event.key == K_LEFT:
            _state = State.Run
            RUN()

        elif event.key == K_SPACE:
            _state = State.Jump
            JUMP()

        else:
            _state = State.Idle
            IDLE()
        return _state

def Image_print(image, x, y):
    for i in range(0, len(image)):
        screen.blit(image[i], [ x, y ] )
    
    

Idle_anims = [Get_Png("Player_Idle1"), Get_Png("Player_Idle2")]
Idle_anim = []
Idle_anim.append(pygame.transform.scale(Idle_anims[0], (70, 60)))
Idle_anim.append(pygame.transform.scale(Idle_anims[1], (70, 60)))
# count = 0

while running:
    for event in pygame.event.get():
        _state = Input(event)
        Animation(_state)

        if event.type == pygame.QUIT:
            running = False

        for i in range(0,len(Idle_anim)):
             
            player = Idle_anim
            Test = Image_print(player, 200, 250)
            
        
        pygame.display.update()
    

pygame.quit()
#endregion
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#region
import pygame
import sys
from pygame.locals import *
import time

SCREEN_WIDTH = 640
SCREEN_HEIGHT = 480

white = (255, 255, 255)
blue = (0, 0, 128)

pygame.init()
pygame.display.set_caption("Python_Project")
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))


pos_x = 200
pos_y = 200

clock = pygame.time.Clock()

def Get_Png(PngName):
    return pygame.image.load(PngName+".png")

def Image_print(image, x, y):
        screen.blit(image, [ x, y ] )

char1 = Get_Png("Player_Idle1")
char2 = pygame.transform.flip(Get_Png("Player_Idle2"), True, False)

running = True

walkRight =[pygame.transform.scale(pygame.image.load('Player_Run1.png'),(80,80)),
            pygame.transform.scale(pygame.image.load('Player_Run2.png'),(80,80)),
            pygame.transform.scale(pygame.image.load('Player_Run3.png'),(80,80)),
            pygame.transform.scale(pygame.image.load('Player_Run2.png'),(80,80))]
            # pygame.transform.scale(pygame.image.load('Player_Run2.png'),(80,80)),
 
# walkLeft = [pygame.transform.rotozoom(pygame.transform.flip(pygame.image.load('Player_Run1.png'),True, False),1,0.35),
#             pygame.transform.rotozoom(pygame.transform.flip(pygame.image.load('Player_Run3.png'),True, False),1,0.35)]


left = False
right = False
stopd = True

def Trans(state):
    if state == "Left":
        left = True
        right = False
        stopd = False
    elif state == "Right":
        left = False
        right = True
        stopd = False
    else:
        left = False
        right = False
        stopd = True

count = 0

start = pygame.time.get_ticks()
end = pygame.time.get_ticks()

result = 0
PlusOk = False

while running:

    clock.tick(60)

    start = pygame.time.get_ticks()

    if (PlusOk == True):
        result = 0

    if count >= 4:
        count = 0

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    key_event = pygame.key.get_pressed()

    if key_event[pygame.K_LEFT]:
        left = True
        right = False
        stopd = False
        pos_x -= 1

    if key_event[pygame.K_RIGHT]:
        left = False
        right = True
        stopd = False
        pos_x += 1

    if key_event[pygame.K_SPACE]:
        left = False
        right = False
        stopd = True
        pos_y -= 10
    else:
        pos_y += 1

    screen.fill(blue)
    screen.blit(walkRight[count], [ pos_x, pos_y ])

    end = pygame.time.get_ticks()
    result += end - start

    # print (result)
    if (result >= 0.4):
        count += 1
        PlusOk = True
    else:
        PlusOk = False
    
    
    
    pygame.display.update()
    #endregion
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame
import sys
import random
from pygame.locals import *

SCREEN_WIDTH = 640
SCREEN_HEIGHT = 480

white = (255, 255, 255)
blue = (0, 0, 128)

pygame.init()
pygame.display.set_caption("Simple PyGame Example")
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))

pos_x = 200
pos_y = 200

def Get_Png(PngName):
    return pygame.image.load(PngName+".png")
    
def Image_print(image, x, y):
    for i in range(0, len(image)):
        screen.blit(image[i], [ x, y ] )

clock = pygame.time.Clock()

running = True

while running:
    clock.tick(60)

    obstacleTrans = random.randrange(1, 7) # TODO

    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    key_event = pygame.key.get_pressed()
    
    if key_event[pygame.K_SPACE]:
        pos_y -= 5
        if (pos_y <= 0 + 20):
            pos_y = 0 + 20
    else:
        pos_y += 3
        if (pos_y >= SCREEN_HEIGHT - 20):
            pos_y = SCREEN_HEIGHT - 20

    screen.fill(blue)
    screen.blit(Get_Png("BackGround"), [pos_x + 60, pos_y + 60])
    pygame.draw.circle(screen, white, (pos_x, pos_y), 20)
    pygame.display.update()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
